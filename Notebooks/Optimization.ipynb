# %%
# Just to know last time this was run:
import time
print(time.ctime())
# Out:
# Wed Nov 29 14:26:07 2017

# %% [markdown]
# # H Optimizing code writing

# %% [markdown]
# This is part of the Python lecture given by Christophe Morisset at IA-UNAM. More informations at: http://python-astro.blogspot.mx/

# %%
import numpy as np
from IPython.core.display import Image

# %% [markdown]
# ### Profiling the code: CPU usage

# %%
# %%writefile test_1_prof.py

import numpy as np
import os
from urllib.request import urlopen
# In python 2, it was:
# from urllib2 import urlopen
from scipy.integrate import simps

class Stel_Spectrum(object):
    """
    This object downloads a file from http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/
    and is able to make some plots.    
    """
    
    spec_count = 0 # This attibute is at the level of the class, not of the object.
    def __init__(self, filename=None, T=None, logg=None, verbose=False):
        """
        Initialisation of the Stel_Spectrum object.
        Parameter:
            - filename
            - T: temperature in K, e.g. 150000
            - logg: e.g. 7.5
            - verbose: if True, some info are printed out
        The wl variable is an array of wavelengths in Angstrom.
        The fl variable is the flux in erg/s/cm2/A
        The variables T and logg are properties: changing them will reload the data
        """
        self.verbose = verbose
        if filename is None:
            if T is not None and logg is not None:
                self.__T = T # We need to initialize the hidden values, as logg is still not defined
                self.logg = logg
                self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            else:
                raise TypeError("T and logg must be given")
        else:
            self.filename = filename
            self.__T = float(filename.split('_')[0]) # We need to initialize the hidden values, as logg is still not defined
            self.logg = float(filename.split('_')[1])
        Stel_Spectrum.spec_count += 1
        if self.verbose:
            print('Instantiation done')
            
    def dlfile(self):
        """
        Downloading file if not already here. Put it in the current directory
        """
        if not os.path.exists(self.filename):
            if self.verbose:
                print('Downloading {}'.format(self.filename))
            try:
                stel_file = urlopen('http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/' + 
                                            self.filename)
                output = open(self.filename,'wb')
                output.write(stel_file.read())
                output.close()
                self.file_found=True
            except:
                if self.verbose:
                    print('file {} not found'.format(self.filename))
                self.file_found=False
        else:
            if self.verbose:
                print('{} already on disk'.format(self.filename))
            self.file_found=True
                
    def read_data(self):
        """
        read the data from the file
        """
        if self.file_found:
            data = np.genfromtxt(self.filename, comments='*', names='wl, fl')
            self.fl = data['fl']
            self.wl = data['wl'] # in A
            self.fl /= 1e8 # F LAMBDA  GIVEN IN ERG/CM**2/SEC/CM -> erg/s/cm2/A
            if self.verbose:
                print('Read data from {}'.format(self.filename))
        else:
            if self.verbose:
                print('file not found {}'.format(self.filename))
            self.wl = None
            self.fl = None
        
    def plot_spr(self, ax=None, *args, **kwargs):
        """
        Plot the spectrum.
        Parameter:
            - ax: an axis (optionnal). If Noe or absent, axis is created
            - any extra parameter is passed to ax.plot
        """
        if self.wl is None:
            print('No data to plot')
            return
        if ax is None:
            fig, ax = plt.subplots()
        ax.plot(self.wl, self.fl,
                label='T3={0:.0f}, logg={1}'.format(self.T/1e3, self.logg),
                *args, **kwargs) # Here are the transmissions of extra parameters to plot
        ax.set_yscale('log')
        ax.set_ylim(1e6, 1e14)
        ax.set_xlabel('Wavelength (A)')
        
    def get_integ(self):
        """
        Return the integral of Flambda over lambda, in erg/s/cm2
        """
        if self.wl is None:
            print('No data')
            return None
        return simps(self.fl, self.wl) # perform the integral
    
    def __getT(self): 
        return self.__T
    
    def __setT(self, value): 
        if not isinstance(value, (int, long, float)): # check the type of the input
            raise TypeError('T must be an integer or a float')
        if float(value) not in np.linspace(40000, 190000, 16): # check the value of the input
            raise ValueError('T value must be between 40000 and 190000K, by 10000K steps')
        elif self.__T != value:
            self.__T = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __delT(self): 
        print('T is needed')
        
    T = property(__getT, __setT, __delT, "Stellar effective temperature")
    
    def __getlogg(self): 
        return self.__logg
    
    def __setlogg(self, value):
        try:
            self.__logg 
        except:
            self.__logg = -1
        if not isinstance(value, (int, float)):
            raise TypeError('logg must be an integer or a float')
        if float(value) not in (-1., 5., 6., 7. ,8., 9.):
            raise ValueError('Error, logg must be 6, 7, 8, or 9')
            self.__logg = None
        elif self.__logg != value:
            self.__logg = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __dellogg(self): 
        print('logg is needed')
        
    logg = property(__getlogg, __setlogg, __dellogg, "Stellar logg")

    def print_info(self):
        """
        Print out the filename and the number of points
        """
        print(self.__repr__())
        
    def __repr__(self):
        """
        This is what is used when calling "print <obj>" or <obj> ENTER
        """
        if self.wl is None:
            return'Filename: {0}, No data'.format(self.filename)
        else:
            return'Filename: {0}, number of points: {1}'.format(self.filename, len(self.wl))
    
    def __del__(self):
        Stel_Spectrum.spec_count -= 1

spectra = [] # we create an empty list
for T in np.linspace(40000, 190000, 4): # this is the list of available temperature (check the site)
    spectra.append(Stel_Spectrum(T=T, logg=6, verbose=True)) # we fill the list with the objects for each temperature
T = np.array([sp.T for sp in spectra])
F = np.array([sp.get_integ() for sp in spectra])
for t, f in zip(T, F):
    print('Temperature = {0:.0f}K, Flux = {1:.2e} erg/s/cm2'.format(t, f))
# Out:
# Overwriting test_1_prof.py

# %%
# %run -t test_1_prof.py
# Out:
# 0040000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0040000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0090000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0090000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0140000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0140000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0190000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0190000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# Temperature = 40000K, Flux = 4.00e+13 erg/s/cm2
# Temperature = 90000K, Flux = 1.05e+15 erg/s/cm2
# Temperature = 140000K, Flux = 6.93e+15 erg/s/cm2
# Temperature = 190000K, Flux = 2.35e+16 erg/s/cm2
#
# IPython CPU timings (estimated):
#   User   :       0.38 s.
#   System :       0.02 s.
# Wall time:       0.40 s.

# %%
# %run -p test_1_prof.py
# Out:
# 0040000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0040000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0090000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0090000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0140000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0140000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0190000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0190000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# Temperature = 40000K, Flux = 4.00e+13 erg/s/cm2
# Temperature = 90000K, Flux = 1.05e+15 erg/s/cm2
# Temperature = 140000K, Flux = 6.93e+15 erg/s/cm2
# Temperature = 190000K, Flux = 2.35e+16 erg/s/cm2

# %%
# Inserting @profile before some functions leads to detailed report on the corresponding functions

# %%
# %%writefile test_2_prof.py

import numpy as np
import os
from urllib.request import urlopen
# In python 2, it was:
# from urllib2 import urlopen
from scipy.integrate import simps

class Stel_Spectrum(object):
    """
    This object downloads a file from http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/
    and is able to make some plots.    
    """
    
    spec_count = 0 # This attibute is at the level of the class, not of the object.
    
    @profile
    def __init__(self, filename=None, T=None, logg=None, verbose=False):
        """
        Initialisation of the Stel_Spectrum object.
        Parameter:
            - filename
            - T: temperature in K, e.g. 150000
            - logg: e.g. 7.5
            - verbose: if True, some info are printed out
        The wl variable is an array of wavelengths in Angstrom.
        The fl variable is the flux in erg/s/cm2/A
        The variables T and logg are properties: changing them will reload the data
        """
        self.verbose = verbose
        if filename is None:
            if T is not None and logg is not None:
                self.__T = T # We need to initialize the hidden values, as logg is still not defined
                self.logg = logg
                self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            else:
                raise TypeError("T and logg must be given")
        else:
            self.filename = filename
            self.__T = float(filename.split('_')[0]) # We need to initialize the hidden values, as logg is still not defined
            self.logg = float(filename.split('_')[1])
        Stel_Spectrum.spec_count += 1
        if self.verbose:
            print('Instantiation done')

    @profile
    def dlfile(self):
        """
        Downloading file if not already here. Put it in the current directory
        """
        if not os.path.exists(self.filename):
            if self.verbose:
                print('Downloading {}'.format(self.filename))
            try:
                stel_file = urlopen('http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/' + 
                                            self.filename)
                output = open(self.filename,'wb')
                output.write(stel_file.read())
                output.close()
                self.file_found=True
            except:
                if self.verbose:
                    print('file {} not found'.format(self.filename))
                self.file_found=False
        else:
            if self.verbose:
                print('{} already on disk'.format(self.filename))
            self.file_found=True
    
    @profile
    def read_data(self):
        """
        read the data from the file
        """
        if self.file_found:
            data = np.genfromtxt(self.filename, comments='*', names='wl, fl')
            self.fl = data['fl']
            self.wl = data['wl'] # in A
            self.fl /= 1e8 # F LAMBDA  GIVEN IN ERG/CM**2/SEC/CM -> erg/s/cm2/A
            if self.verbose:
                print('Read data from {}'.format(self.filename))
        else:
            if self.verbose:
                print('file not found {}'.format(self.filename))
            self.wl = None
            self.fl = None
        
    def plot_spr(self, ax=None, *args, **kwargs):
        """
        Plot the spectrum.
        Parameter:
            - ax: an axis (optionnal). If Noe or absent, axis is created
            - any extra parameter is passed to ax.plot
        """
        if self.wl is None:
            print('No data to plot')
            return
        if ax is None:
            fig, ax = plt.subplots()
        ax.plot(self.wl, self.fl,
                label='T3={0:.0f}, logg={1}'.format(self.T/1e3, self.logg),
                *args, **kwargs) # Here are the transmissions of extra parameters to plot
        ax.set_yscale('log')
        ax.set_ylim(1e6, 1e14)
        ax.set_xlabel('Wavelength (A)')
        
    def get_integ(self):
        """
        Return the integral of Flambda over lambda, in erg/s/cm2
        """
        if self.wl is None:
            print('No data')
            return None
        return simps(self.fl, self.wl) # perform the integral
    
    def __getT(self): 
        return self.__T
    
    def __setT(self, value): 
        if not isinstance(value, (int, long, float)): # check the type of the input
            raise TypeError('T must be an integer or a float')
        if float(value) not in np.linspace(40000, 190000, 16): # check the value of the input
            raise ValueError('T value must be between 40000 and 190000K, by 10000K steps')
        elif self.__T != value:
            self.__T = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __delT(self): 
        print('T is needed')
        
    T = property(__getT, __setT, __delT, "Stellar effective temperature")
    
    def __getlogg(self): 
        return self.__logg

    @profile
    def __setlogg(self, value):
        try:
            self.__logg 
        except:
            self.__logg = -1
        if not isinstance(value, (int, long, float)):
            raise TypeError('logg must be an integer or a float')
        if float(value) not in (-1., 5., 6., 7. ,8., 9.):
            raise ValueError('Error, logg must be 6, 7, 8, or 9')
            self.__logg = None
        elif self.__logg != value:
            self.__logg = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __dellogg(self): 
        print('logg is needed')
        
    logg = property(__getlogg, __setlogg, __dellogg, "Stellar logg")

    def print_info(self):
        """
        Print out the filename and the number of points
        """
        print(self.__repr__())
        
    def __repr__(self):
        """
        This is what is used when calling "print <obj>" or <obj> ENTER
        """
        if self.wl is None:
            return'Filename: {0}, No data'.format(self.filename)
        else:
            return'Filename: {0}, number of points: {1}'.format(self.filename, len(self.wl))
    
    def __del__(self):
        Stel_Spectrum.spec_count -= 1

spectra = [] # we create an empty list
for T in np.linspace(40000, 190000, 4): # this is the list of available temperature (check the site)
    spectra.append(Stel_Spectrum(T=T, logg=6, verbose=True)) # we fill the list with the objects for each temperature
T = np.array([sp.T for sp in spectra])
F = np.array([sp.get_integ() for sp in spectra])
for t, f in zip(T, F):
    print('Temperature = {0:.0f}K, Flux = {1:.2e} erg/s/cm2'.format(t, f))
# Out:
# Overwriting test_2_prof.py

# %%
# Need to pip install line-profiler
! kernprof -l -v test_2_prof.py
# Out:
# Wrote profile results to test_2_prof.py.lprof
# Timer unit: 1e-06 s
#
# Total time: 2.2e-05 s
# File: test_2_prof.py
# Function: __init__ at line 17
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     17                                               @profile
#     18                                               def __init__(self, filename=None, T=None, logg=None, verbose=False):
#     19                                                   """
#     20                                                   Initialisation of the Stel_Spectrum object.
#     21                                                   Parameter:
#     22                                                       - filename
#     23                                                       - T: temperature in K, e.g. 150000
#     24                                                       - logg: e.g. 7.5
#     25                                                       - verbose: if True, some info are printed out
#     26                                                   The wl variable is an array of wavelengths in Angstrom.
#     27                                                   The fl variable is the flux in erg/s/cm2/A
#     28                                                   The variables T and logg are properties: changing them will reload the data
#     29                                                   """
#     30         1            2      2.0      9.1          self.verbose = verbose
#     31         1            1      1.0      4.5          if filename is None:
#     32         1            1      1.0      4.5              if T is not None and logg is not None:
#     33         1            1      1.0      4.5                  self.__T = T # We need to initialize the hidden values, as logg is still not defined
#     34         1           17     17.0     77.3                  self.logg = logg
#     35                                                           self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
#     36                                                       else:
#     37                                                           raise TypeError("T and logg must be given")
#     38                                                   else:
#     39                                                       self.filename = filename
#     40                                                       self.__T = float(filename.split('_')[0]) # We need to initialize the hidden values, as logg is still not defined
#     41                                                       self.logg = float(filename.split('_')[1])
#     42                                                   Stel_Spectrum.spec_count += 1
#     43                                                   if self.verbose:
#     44                                                       print('Instantiation done')
#
# Total time: 0 s
# File: test_2_prof.py
# Function: dlfile at line 46
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     46                                               @profile
#     47                                               def dlfile(self):
#     48                                                   """
#     49                                                   Downloading file if not already here. Put it in the current directory
#     50                                                   """
#     51                                                   if not os.path.exists(self.filename):
#     52                                                       if self.verbose:
#     53                                                           print('Downloading {}'.format(self.filename))
#     54                                                       try:
#     55                                                           stel_file = urlopen('http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/' +
#     56                                                                                       self.filename)
#     57                                                           output = open(self.filename,'wb')
#     58                                                           output.write(stel_file.read())
#     59                                                           output.close()
#     60                                                           self.file_found=True
#     61                                                       except:
#     62                                                           if self.verbose:
#     63                                                               print('file {} not found'.format(self.filename))
#     64                                                           self.file_found=False
#     65                                                   else:
#     66                                                       if self.verbose:
#     67                                                           print('{} already on disk'.format(self.filename))
#     68                                                       self.file_found=True
#
# Total time: 0 s
# File: test_2_prof.py
# Function: read_data at line 70
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     70                                               @profile
#     71                                               def read_data(self):
#     72                                                   """
#     73                                                   read the data from the file
#     74                                                   """
#     75                                                   if self.file_found:
#     76                                                       data = np.genfromtxt(self.filename, comments='*', names='wl, fl')
#     77                                                       self.fl = data['fl']
#     78                                                       self.wl = data['wl'] # in A
#     79                                                       self.fl /= 1e8 # F LAMBDA  GIVEN IN ERG/CM**2/SEC/CM -> erg/s/cm2/A
#     80                                                       if self.verbose:
#     81                                                           print('Read data from {}'.format(self.filename))
#     82                                                   else:
#     83                                                       if self.verbose:
#     84                                                           print('file not found {}'.format(self.filename))
#     85                                                       self.wl = None
#     86                                                       self.fl = None
#
# Total time: 8e-06 s
# File: test_2_prof.py
# Function: __setlogg at line 138
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    138                                               @profile
#    139                                               def __setlogg(self, value):
#    140         1            1      1.0     12.5          try:
#    141         1            3      3.0     37.5              self.__logg
#    142         1            0      0.0      0.0          except:
#    143         1            2      2.0     25.0              self.__logg = -1
#    144         1            2      2.0     25.0          if not isinstance(value, (int, long, float)):
#    145                                                       raise TypeError('logg must be an integer or a float')
#    146                                                   if float(value) not in (-1., 5., 6., 7. ,8., 9.):
#    147                                                       raise ValueError('Error, logg must be 6, 7, 8, or 9')
#    148                                                       self.__logg = None
#    149                                                   elif self.__logg != value:
#    150                                                       self.__logg = value
#    151                                                       self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
#    152                                                       self.dlfile() # will download new data
#    153                                                       self.read_data() # will update the data
#
# Traceback (most recent call last):
#   File "/home/vero/anaconda2/envs/ipy3/bin/kernprof", line 11, in <module>
#     sys.exit(main())
#   File "/home/vero/anaconda2/envs/ipy3/lib/python3.6/site-packages/kernprof.py", line 222, in main
#     execfile(script_file, ns, ns)
#   File "/home/vero/anaconda2/envs/ipy3/lib/python3.6/site-packages/kernprof.py", line 35, in execfile
#     exec_(compile(f.read(), filename, 'exec'), globals, locals)
#   File "test_2_prof.py", line 180, in <module>
#     spectra.append(Stel_Spectrum(T=T, logg=6, verbose=True)) # we fill the list with the objects for each temperature
#   File "/home/vero/anaconda2/envs/ipy3/lib/python3.6/site-packages/line_profiler.py", line 104, in wrapper
#     result = func(*args, **kwds)
#   File "test_2_prof.py", line 34, in __init__
#     self.logg = logg
#   File "/home/vero/anaconda2/envs/ipy3/lib/python3.6/site-packages/line_profiler.py", line 104, in wrapper
#     result = func(*args, **kwds)
#   File "test_2_prof.py", line 144, in __setlogg
#     if not isinstance(value, (int, long, float)):
# NameError: name 'long' is not defined

# %%
# Use the test_1 because @profile is not compatible
! python -m cProfile -o test_1_prof.prof test_1_prof.py
# Out:
# 0040000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0040000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0090000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0090000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0140000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0140000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# 0190000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0190000_6.00_33_50_02_15.bin_0.1.gz
# Instantiation done
# Temperature = 40000K, Flux = 4.00e+13 erg/s/cm2
# Temperature = 90000K, Flux = 1.05e+15 erg/s/cm2
# Temperature = 140000K, Flux = 6.93e+15 erg/s/cm2
# Temperature = 190000K, Flux = 2.35e+16 erg/s/cm2

# %%
# need to pip install gprof2dot
# dot is installed by sudo yum/dnf install graphviz
! gprof2dot -f pstats test_1_prof.prof | dot -Tpng -o test_1-prof.png

# %%
Image(filename='test_1-prof.png')

# %%
import pstats
p = pstats.Stats('test_1_prof.prof')
p.strip_dirs().sort_stats('time').print_stats(10);
# Out:
# Wed Nov 29 14:26:23 2017    test_1_prof.prof
#
#          1405947 function calls (1402143 primitive calls) in 0.638 seconds
#
#    Ordered by: internal time
#    List reduced from 1572 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         4    0.105    0.026    0.509    0.127 npyio.py:1316(genfromtxt)
#     79896    0.069    0.000    0.189    0.000 _iotools.py:217(_delimited_splitter)
#     79896    0.044    0.000    0.053    0.000 {method 'readline' of '_io.BufferedReader' objects}
#     79938    0.039    0.000    0.074    0.000 py3k.py:32(asbytes)
#    159608    0.036    0.000    0.036    0.000 _iotools.py:690(_loose_call)
#    159704    0.036    0.000    0.036    0.000 {method 'split' of 'bytes' objects}
#     79896    0.035    0.000    0.117    0.000 gzip.py:372(readline)
#     62/57    0.023    0.000    0.027    0.000 {built-in method _imp.create_dynamic}
#     79896    0.019    0.000    0.029    0.000 _compression.py:12(_check_not_closed)
#       266    0.019    0.000    0.019    0.000 {built-in method marshal.loads}

# %% [markdown]
# ### Profiling the code: RAM memory usage

# %%
# %%writefile test_3_prof.py

import numpy as np
import os
from urllib.request import urlopen
# In python 2, it was:
# from urllib2 import urlopen
from scipy.integrate import simps
from memory_profiler import profile

class Stel_Spectrum(object):
    """
    This object downloads a file from http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/
    and is able to make some plots.    
    """
    
    spec_count = 0 # This attibute is at the level of the class, not of the object.
    
    @profile
    def __init__(self, filename=None, T=None, logg=None, verbose=False):
        """
        Initialisation of the Stel_Spectrum object.
        Parameter:
            - filename
            - T: temperature in K, e.g. 150000
            - logg: e.g. 7.5
            - verbose: if True, some info are printed out
        The wl variable is an array of wavelengths in Angstrom.
        The fl variable is the flux in erg/s/cm2/A
        The variables T and logg are properties: changing them will reload the data
        """
        self.verbose = verbose
        if filename is None:
            if T is not None and logg is not None:
                self.__T = T # We need to initialize the hidden values, as logg is still not defined
                self.logg = logg
                self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            else:
                raise TypeError("T and logg must be given")
        else:
            self.filename = filename
            self.__T = float(filename.split('_')[0]) # We need to initialize the hidden values, as logg is still not defined
            self.logg = float(filename.split('_')[1])
        Stel_Spectrum.spec_count += 1
        if self.verbose:
            print('Instantiation done')
            
    def dlfile(self):
        """
        Downloading file if not already here. Put it in the current directory
        """
        if not os.path.exists(self.filename):
            if self.verbose:
                print('Downloading {}'.format(self.filename))
            try:
                stel_file = urlopen('http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/' + 
                                            self.filename)
                output = open(self.filename,'wb')
                output.write(stel_file.read())
                output.close()
                self.file_found=True
            except:
                if self.verbose:
                    print('file {} not found'.format(self.filename))
                self.file_found=False
        else:
            if self.verbose:
                print('{} already on disk'.format(self.filename))
            self.file_found=True
                
    def read_data(self):
        """
        read the data from the file
        """
        if self.file_found:
            data = np.genfromtxt(self.filename, comments='*', names='wl, fl')
            self.fl = data['fl']
            self.wl = data['wl'] # in A
            self.fl /= 1e8 # F LAMBDA  GIVEN IN ERG/CM**2/SEC/CM -> erg/s/cm2/A
            if self.verbose:
                print('Read data from {}'.format(self.filename))
        else:
            if self.verbose:
                print('file not found {}'.format(self.filename))
            self.wl = None
            self.fl = None
        
    def plot_spr(self, ax=None, *args, **kwargs):
        """
        Plot the spectrum.
        Parameter:
            - ax: an axis (optionnal). If Noe or absent, axis is created
            - any extra parameter is passed to ax.plot
        """
        if self.wl is None:
            print('No data to plot')
            return
        if ax is None:
            fig, ax = plt.subplots()
        ax.plot(self.wl, self.fl,
                label='T3={0:.0f}, logg={1}'.format(self.T/1e3, self.logg),
                *args, **kwargs) # Here are the transmissions of extra parameters to plot
        ax.set_yscale('log')
        ax.set_ylim(1e6, 1e14)
        ax.set_xlabel('Wavelength (A)')
        
    @profile
    def get_integ(self):
        """
        Return the integral of Flambda over lambda, in erg/s/cm2
        """
        if self.wl is None:
            print('No data')
            return None
        return simps(self.fl, self.wl) # perform the integral
    
    def __getT(self): 
        return self.__T
    
    def __setT(self, value): 
        if not isinstance(value, (int, long, float)): # check the type of the input
            raise TypeError('T must be an integer or a float')
        if float(value) not in np.linspace(40000, 190000, 16): # check the value of the input
            raise ValueError('T value must be between 40000 and 190000K, by 10000K steps')
        elif self.__T != value:
            self.__T = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __delT(self): 
        print('T is needed')
        
    T = property(__getT, __setT, __delT, "Stellar effective temperature")
    
    def __getlogg(self): 
        return self.__logg
    
    @profile
    def __setlogg(self, value):
        try:
            self.__logg 
        except:
            self.__logg = -1
        if not isinstance(value, (int, float)):
            raise TypeError('logg must be an integer or a float')
        if float(value) not in (-1., 5., 6., 7. ,8., 9.):
            raise ValueError('Error, logg must be 6, 7, 8, or 9')
            self.__logg = None
        elif self.__logg != value:
            self.__logg = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __dellogg(self): 
        print('logg is needed')
        
    logg = property(__getlogg, __setlogg, __dellogg, "Stellar logg")

    def print_info(self):
        """
        Print out the filename and the number of points
        """
        print(self.__repr__())
        
    def __repr__(self):
        """
        This is what is used when calling "print <obj>" or <obj> ENTER
        """
        if self.wl is None:
            return'Filename: {0}, No data'.format(self.filename)
        else:
            return'Filename: {0}, number of points: {1}'.format(self.filename, len(self.wl))
    
    def __del__(self):
        Stel_Spectrum.spec_count -= 1


sp = Stel_Spectrum(T=100000, logg=6, verbose=True)
print('Temperature = {0:.0f}K, Flux = {1:.2e} erg/s/cm2'.format(sp.T, sp.get_integ()))
# Out:
# Overwriting test_3_prof.py

# %%
# need to pip install memory_profiler
# need to pip install psutil
! python -m memory_profiler test_3_prof.py
# Out:
# 0100000_6.00_33_50_02_15.bin_0.1.gz already on disk
# Read data from 0100000_6.00_33_50_02_15.bin_0.1.gz
# Filename: test_3_prof.py
#
# Line #    Mem usage    Increment   Line Contents
# ================================================
#    138     67.1 MiB     67.1 MiB       @profile
#    139                                 def __setlogg(self, value):
#    140     67.1 MiB      0.0 MiB           try:
#    141     67.1 MiB      0.0 MiB               self.__logg
#    142     67.1 MiB      0.0 MiB           except:
#    143     67.1 MiB      0.0 MiB               self.__logg = -1
#    144     67.1 MiB      0.0 MiB           if not isinstance(value, (int, float)):
#    145                                         raise TypeError('logg must be an integer or a float')
#    146     67.1 MiB      0.0 MiB           if float(value) not in (-1., 5., 6., 7. ,8., 9.):
#    147                                         raise ValueError('Error, logg must be 6, 7, 8, or 9')
#    148                                         self.__logg = None
#    149     67.1 MiB      0.0 MiB           elif self.__logg != value:
#    150     67.1 MiB      0.0 MiB               self.__logg = value
#    151     67.1 MiB      0.0 MiB               self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
#    152     67.1 MiB      0.0 MiB               self.dlfile() # will download new data
#    153     69.2 MiB      2.1 MiB               self.read_data() # will update the data
#
#
# Instantiation done
# Filename: test_3_prof.py
#
# Line #    Mem usage    Increment   Line Contents
# ================================================
#     18     67.0 MiB     67.0 MiB       @profile
#     19                                 def __init__(self, filename=None, T=None, logg=None, verbose=False):
#     20                                     """
#     21                                     Initialisation of the Stel_Spectrum object.
#     22                                     Parameter:
#     23                                         - filename
#     24                                         - T: temperature in K, e.g. 150000
#     25                                         - logg: e.g. 7.5
#     26                                         - verbose: if True, some info are printed out
#     27                                     The wl variable is an array of wavelengths in Angstrom.
#     28                                     The fl variable is the flux in erg/s/cm2/A
#     29                                     The variables T and logg are properties: changing them will reload the data
#     30                                     """
#     31     67.0 MiB      0.0 MiB           self.verbose = verbose
#     32     67.0 MiB      0.0 MiB           if filename is None:
#     33     67.0 MiB      0.0 MiB               if T is not None and logg is not None:
#     34     67.0 MiB      0.0 MiB                   self.__T = T # We need to initialize the hidden values, as logg is still not defined
#     35     69.2 MiB      2.2 MiB                   self.logg = logg
#     36     69.2 MiB      0.0 MiB                   self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
#     37                                         else:
#     38                                             raise TypeError("T and logg must be given")
#     39                                     else:
#     40                                         self.filename = filename
#     41                                         self.__T = float(filename.split('_')[0]) # We need to initialize the hidden values, as logg is still not defined
#     42                                         self.logg = float(filename.split('_')[1])
#     43     69.2 MiB      0.0 MiB           Stel_Spectrum.spec_count += 1
#     44     69.2 MiB      0.0 MiB           if self.verbose:
#     45     69.2 MiB      0.0 MiB               print('Instantiation done')
#
#
# Filename: test_3_prof.py
#
# Line #    Mem usage    Increment   Line Contents
# ================================================
#    106     69.2 MiB     69.2 MiB       @profile
#    107                                 def get_integ(self):
#    108                                     """
#    109                                     Return the integral of Flambda over lambda, in erg/s/cm2
#    110                                     """
#    111     69.2 MiB      0.0 MiB           if self.wl is None:
#    112                                         print('No data')
#    113                                         return None
#    114     69.5 MiB      0.3 MiB           return simps(self.fl, self.wl) # perform the integral
#
#
# Temperature = 100000K, Flux = 1.79e+15 erg/s/cm2

# %% [markdown]
# ### Debugger

# %% [markdown]
# #### From the terminal

# %%
# ! ipython -m pdb test_1_prof.py # from a terminal

# %% [markdown]
# #### Breakpoint

# %%
# import pdb # need to call the debugger at the breakpoint
# Inserting a pdb.set_trace in the __init__ method to stop the program and inspect it

# %%
# %%writefile test_5_pdb.py
import pdb # This is needed to use the debugger
import numpy as np
import os
from urllib.request import urlopen
# In python 2, it was:
# from urllib2 import urlopen
from scipy.integrate import simps

class Stel_Spectrum(object):
    """
    This object downloads a file from http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/
    and is able to make some plots.    
    """
    
    spec_count = 0 # This attibute is at the level of the class, not of the object.
    def __init__(self, filename=None, T=None, logg=None, verbose=False):
        """
        Initialisation of the Stel_Spectrum object.
        Parameter:
            - filename
            - T: temperature in K, e.g. 150000
            - logg: e.g. 7.5
            - verbose: if True, some info are printed out
        The wl variable is an array of wavelengths in Angstrom.
        The fl variable is the flux in erg/s/cm2/A
        The variables T and logg are properties: changing them will reload the data
        """
        pdb.set_trace() # THIS IS A BREAKPOINT
        self.verbose = verbose
        if filename is None:
            if T is not None and logg is not None:
                self.__T = T # We need to initialize the hidden values, as logg is still not defined
                self.logg = logg
                self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            else:
                raise TypeError("T and logg must be given")
        else:
            self.filename = filename
            self.__T = float(filename.split('_')[0]) # We need to initialize the hidden values, as logg is still not defined
            self.logg = float(filename.split('_')[1])
        Stel_Spectrum.spec_count += 1
        if self.verbose:
            print('Instantiation done')
            
    def dlfile(self):
        """
        Downloading file if not already here. Put it in the current directory
        """
        if not os.path.exists(self.filename):
            if self.verbose:
                print('Downloading {}'.format(self.filename))
            try:
                stel_file = urlopen('http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/' + 
                                            self.filename)
                output = open(self.filename,'wb')
                output.write(stel_file.read())
                output.close()
                self.file_found=True
            except:
                if self.verbose:
                    print('file {} not found'.format(self.filename))
                self.file_found=False
        else:
            if self.verbose:
                print('{} already on disk'.format(self.filename))
            self.file_found=True
                
    def read_data(self):
        """
        read the data from the file
        """
        if self.file_found:
            data = np.genfromtxt(self.filename, comments='*', names='wl, fl')
            self.fl = data['fl']
            self.wl = data['wl'] # in A
            self.fl /= 1e8 # F LAMBDA  GIVEN IN ERG/CM**2/SEC/CM -> erg/s/cm2/A
            if self.verbose:
                print('Read data from {}'.format(self.filename))
        else:
            if self.verbose:
                print('file not found {}'.format(self.filename))
            self.wl = None
            self.fl = None
        
    def plot_spr(self, ax=None, *args, **kwargs):
        """
        Plot the spectrum.
        Parameter:
            - ax: an axis (optionnal). If Noe or absent, axis is created
            - any extra parameter is passed to ax.plot
        """
        if self.wl is None:
            print('No data to plot')
            return
        if ax is None:
            fig, ax = plt.subplots()
        ax.plot(self.wl, self.fl,
                label='T3={0:.0f}, logg={1}'.format(self.T/1e3, self.logg),
                *args, **kwargs) # Here are the transmissions of extra parameters to plot
        ax.set_yscale('log')
        ax.set_ylim(1e6, 1e14)
        ax.set_xlabel('Wavelength (A)')
        
    def get_integ(self):
        """
        Return the integral of Flambda over lambda, in erg/s/cm2
        """
        if self.wl is None:
            print('No data')
            return None
        return simps(self.fl, self.wl) # perform the integral
    
    def __getT(self): 
        return self.__T
    
    def __setT(self, value): 
        if not isinstance(value, (int, long, float)): # check the type of the input
            raise TypeError('T must be an integer or a float')
        if float(value) not in np.linspace(40000, 190000, 16): # check the value of the input
            raise ValueError('T value must be between 40000 and 190000K, by 10000K steps')
        elif self.__T != value:
            self.__T = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __delT(self): 
        print('T is needed')
        
    T = property(__getT, __setT, __delT, "Stellar effective temperature")
    
    def __getlogg(self): 
        return self.__logg
    
    def __setlogg(self, value):
        try:
            self.__logg 
        except:
            self.__logg = -1
        if not isinstance(value, (int, float)):
            raise TypeError('logg must be an integer or a float')
        if float(value) not in (-1., 5., 6., 7. ,8., 9.):
            raise ValueError('Error, logg must be 6, 7, 8, or 9')
            self.__logg = None
        elif self.__logg != value:
            self.__logg = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __dellogg(self): 
        print('logg is needed')
        
    logg = property(__getlogg, __setlogg, __dellogg, "Stellar logg")

    def print_info(self):
        """
        Print out the filename and the number of points
        """
        print(self.__repr__())
        
    def __repr__(self):
        """
        This is what is used when calling "print <obj>" or <obj> ENTER
        """
        if self.wl is None:
            return'Filename: {0}, No data'.format(self.filename)
        else:
            return'Filename: {0}, number of points: {1}'.format(self.filename, len(self.wl))
    
    def __del__(self):
        Stel_Spectrum.spec_count -= 1

sp = Stel_Spectrum(T=100000, logg=6)
print('ending')
print(sp.filename)
# Out:
# Overwriting test_5_pdb.py

# %% [markdown]
# The commands that can be used once inside the pdb debugger session are:
# * l(list)	Lists the code at the current position
# * u(p)	    Walk up the call stack
# * d(own)	Walk down the call stack
# * n(ext)	Execute the next line (does not go down in new functions)
# * s(tep)	Execute the next statement (goes down in new functions)
# * bt	    Print the call stack
# * a	        Print the local variables
# * !command	Execute the given Python command (by opposition to pdb commands
# * break N   Set a breakpoint at line number N. If no N, list all the breakpoints
# * disable N Remove the breakpoin number N
# * c(ontinue) Run until the next breakpoint or the end of the program
# * return   Continues executing until the function is about to execute a return statement, and then it pauses. This gives you time to look at the return value before the function returns.

# %%
# %run test_5_pdb.py
# Out:
# > /home/vero/vgomez@astro.unam.mx/Doctorado/Curso_Python/VGomezLlanos_python/Notebooks/test_5_pdb.py(29)__init__()
# -> self.verbose = verbose
# (Pdb) c
# ending
# 0100000_6.00_33_50_02_15.bin_0.1.gz

# %%
# %%writefile test_6_pdb.py
import numpy as np
import os
from urllib.request import urlopen
# In python 2, it was:
# from urllib2 import urlopen
from scipy.integrate import simps

class Stel_Spectrum(object):
    """
    This object downloads a file from http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/
    and is able to make some plots.    
    """
    
    spec_count = 0 # This attibute is at the level of the class, not of the object.
    def __init__(self, filename=None, T=None, logg=None, verbose=False):
        """
        Initialisation of the Stel_Spectrum object.
        Parameter:
            - filename
            - T: temperature in K, e.g. 150000
            - logg: e.g. 7.5
            - verbose: if True, some info are printed out
        The wl variable is an array of wavelengths in Angstrom.
        The fl variable is the flux in erg/s/cm2/A
        The variables T and logg are properties: changing them will reload the data
        """
        self.verbose = verbose
        if filename is None:
            if T is not None and logg is not None:
                self.__T = T # We need to initialize the hidden values, as logg is still not defined
                self.logg = logg
                self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            else:
                raise TypeError("T and logg must be given")
        else:
            self.filename = filename
            self.__T = float(filename.split('_')[0]) # We need to initialize the hidden values, as logg is still not defined
            self.logg = float(filename.split('_')[1])
        Stel_Spectrum.spec_count += 1
        if self.verbose:
            print('Instantiation done')
            
    def dlfile(self):
        """
        Downloading file if not already here. Put it in the current directory
        """
        if not os.path.exists(self.filename):
            if self.verbose:
                print('Downloading {}'.format(self.filename))
            try:
                stel_file = urlopen('http://astro.uni-tuebingen.de/~rauch/TMAF/NLTE/He+C+N+O/' + 
                                            self.filename)
                output = open(self.filename,'wb')
                output.write(stel_file.read())
                output.close()
                self.file_found=True
            except:
                if self.verbose:
                    print('file {} not found'.format(self.filename))
                self.file_found=False
        else:
            if self.verbose:
                print('{} already on disk'.format(self.filenames))
            self.file_found=True
                
    def read_data(self):
        """
        read the data from the file
        """
        if self.file_found:
            data = np.genfromtxt(self.filename, comments='*', names='wl, fl')
            self.fl = data['fl']
            self.wl = data['wl'] # in A
            self.fl /= 1e8 # F LAMBDA  GIVEN IN ERG/CM**2/SEC/CM -> erg/s/cm2/A
            if self.verbose:
                print('Read data from {}'.format(self.filename))
        else:
            if self.verbose:
                print('file not found {}'.format(self.filename))
            self.wl = None
            self.fl = None
        
    def plot_spr(self, ax=None, *args, **kwargs):
        """
        Plot the spectrum.
        Parameter:
            - ax: an axis (optionnal). If Noe or absent, axis is created
            - any extra parameter is passed to ax.plot
        """
        if self.wl is None:
            print('No data to plot')
            return
        if ax is None:
            fig, ax = plt.subplots()
        ax.plot(self.wl, self.fl,
                label='T3={0:.0f}, logg={1}'.format(self.T/1e3, self.logg),
                *args, **kwargs) # Here are the transmissions of extra parameters to plot
        ax.set_yscale('log')
        ax.set_ylim(1e6, 1e14)
        ax.set_xlabel('Wavelength (A)')
        
    def get_integ(self):
        """
        Return the integral of Flambda over lambda, in erg/s/cm2
        """
        if self.wl is None:
            print('No data')
            return None
        return simps(self.fl, self.wl) # perform the integral
    
    def __getT(self): 
        return self.__T
    
    def __setT(self, value): 
        if not isinstance(value, (int, long, float)): # check the type of the input
            raise TypeError('T must be an integer or a float')
        if float(value) not in np.linspace(40000, 190000, 16): # check the value of the input
            raise ValueError('T value must be between 40000 and 190000K, by 10000K steps')
        elif self.__T != value:
            self.__T = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __delT(self): 
        print('T is needed')
        
    T = property(__getT, __setT, __delT, "Stellar effective temperature")
    
    def __getlogg(self): 
        return self.__logg
    
    def __setlogg(self, value):
        try:
            self.__logg 
        except:
            self.__logg = -1
        if not isinstance(value, (int, float)):
            raise TypeError('logg must be an integer or a float')
        if float(value) not in (-1., 5., 6., 7. ,8., 9.):
            raise ValueError('Error, logg must be 6, 7, 8, or 9')
            self.__logg = None
        elif self.__logg != value:
            self.__logg = value
            self.filename = '0{0:06.0f}_{1:.2f}_33_50_02_15.bin_0.1.gz'.format(self.T, self.logg)
            self.dlfile() # will download new data
            self.read_data() # will update the data
        
    def __dellogg(self): 
        print('logg is needed')
        
    logg = property(__getlogg, __setlogg, __dellogg, "Stellar logg")

    def print_info(self):
        """
        Print out the filename and the number of points
        """
        print(self.__repr__())
        
    def __repr__(self):
        """
        This is what is used when calling "print <obj>" or <obj> ENTER
        """
        if self.wl is None:
            return'Filename: {0}, No data'.format(self.filename)
        else:
            return'Filename: {0}, number of points: {1}'.format(self.filename, len(self.wl))
    
    def __del__(self):
        Stel_Spectrum.spec_count -= 1

sp = Stel_Spectrum(T=100000, logg=6, verbose=True)
print('ending')
print(sp.filename)
# Out:
# Overwriting test_6_pdb.py
